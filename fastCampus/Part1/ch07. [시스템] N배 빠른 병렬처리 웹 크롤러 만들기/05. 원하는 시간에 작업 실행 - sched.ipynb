# %% [markdown]
# # **Chapter 7. [시스템] N배 빠른 병렬처리 웹 크롤러 만들기**
#
#
# ---
# ### 📝 **학습 목차**
# > 7-1. 프로젝트 개요 <br>
# > 7-2. 시스템 정보 확인 - platform <br>
# > 7-3. 매개변수 입력 받기 - sys.argv, argparse <br>
# > 7-4. 디버깅의 기본! 로그 남기기 - logging <br>
# > **7-5. 원하는 시간에 작업 실행 - sched** <br>
# > 7-6. 병렬 처리 1 - threading <br>
# > 7-7. 병렬 처리 2 - multiprocessing <br>
# > 7-8. 시스템 명령어 실행 <br>
# > 7-9. 프로젝트 실습

# %% [markdown]
# ## 7-5. 원하는 시간에 작업 실행

# %% [markdown]
# > ### sched
# >  - `sched` 는 지정된 시간 간격으로 원하는 이벤트를 실행하게 하는 이벤트 스케줄러 **표준 라이브러리**
# >  - 사용 순서
# >    - 1. 스케줄러 객체 생성
# >    - 2. enter(`실행 간격(초)`, `우선순위`, `실행할 함수`, `함수에 전달할 인자`) 를 사용하여 실행할 이벤트 등록
# >    - 3. `run()` 스케줄러 실행

# %% [markdown]
# #### 7.5.1. sched 예제
# ① 프로그램 실행 후 5초 후에 print_a() 호출 <br>
# ② 프로그램 실행 후 3초 후에 print_b() 호출 <br>
# ③ 프로그램 실행 후 7초 후에 print_c() 호출

# %%
import sched
import time

start = time.time()

def print_a(a):
    print(round(time.time() - start, 2), ' 초 경과')
    print(a)


def print_b(b):
    print(round(time.time() - start, 2), ' 초 경과')
    print(b)


def print_c(c):
    print(round(time.time() - start, 2), ' 초 경과')
    print(c)


s = sched.scheduler()  # 스케줄러 객체 생성
s.enter(5, 1, print_a, ('print_a 함수 실행됨',))  # 5초 후에 실행
s.enter(3, 1, print_b, ('print_b 함수 실행됨',))  # 3초 후에 실행
s.enter(7, 1, print_c, ('print_c 함수 실행됨',))  # 7초 후에 실행
s.run()
# Out:
# 3.01  초 경과
# print_b 함수 실행됨
# 5.0  초 경과
# print_a 함수 실행됨
# 7.0  초 경과
# print_c 함수 실행됨

# %% [markdown]
# > ### schedule
# >  - `sched` 과 마찬가지로 일정한 시간 간격으로 프로그램을 실행시켜주는 **외장 라이브러리**
# >  - 파이썬의 원하는 함수들을 원하는 실행 주기를 (초, 분, 시간, 요일, 특정 시각) 손쉽게 설정이 가능
# >  - 시간 관련 내장 라이브러리인 `time` 과 주로 함께 사용됨

# %%
import schedule   # pip install scehdule
import time

# %%
def message(interval):
    print(f"{interval}간격 스케줄 실행중...")

# %% [markdown]
# #### 7.5.2. 시, 분, 초 단위 실행

# %% [markdown]
# 5초에 한번씩 함수 실행

# %%
# 5초에 한번씩 함수 실행
schedule.every(5).seconds.do(message, '5초')  # 이벤트 등록
# Out:
# Every 5 seconds do message('5초') (last run: [never], next run: 2024-09-12 11:45:31)

# %%
# 스케줄러 실행
while True:
    schedule.run_pending()
# Out:
# 5초간격 스케줄 실행중...
# 5초간격 스케줄 실행중...
# 5초간격 스케줄 실행중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 스케줄러 실행
#       2 while True:
# ----> 3     schedule.run_pending()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/schedule/__init__.py:854, in run_pending()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/schedule/__init__.py:100, in Scheduler.run_pending(self)
#      90 """
#      91 Run all jobs that are scheduled to run.
#      92
#    (...)
#      97 between but only once.
#      98 """
#      99 runnable_jobs = (job for job in self.jobs if job.should_run)
# --> 100 for job in sorted(runnable_jobs):
#     101     self._run_job(job)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/schedule/__init__.py:99, in <genexpr>(.0)
#      89 def run_pending(self) -> None:
#      90     """
#      91     Run all jobs that are scheduled to run.
#      92
#    (...)
#      97     between but only once.
#      98     """
# ---> 99     runnable_jobs = (job for job in self.jobs if job.should_run)
#     100     for job in sorted(runnable_jobs):
#     101         self._run_job(job)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/schedule/__init__.py:672, in Job.should_run(self)
#     668 """
#     669 :return: ``True`` if the job should be run now.
#     670 """
#     671 assert self.next_run is not None, "must run _schedule_next_run before"
# --> 672 return datetime.datetime.now() >= self.next_run
#
# KeyboardInterrupt:

# %% [markdown]
# 1분에 한번씩 함수 실행

# %%
# 스케줄러 초기화
schedule.clear()

# %%
# 1분에 한번씩 함수 실행
schedule.every(1).minutes.do(message, '1분')  # 이벤트 등록
# Out:
# Every 1 minute do message('1분') (last run: [never], next run: 2024-09-12 11:47:27)

# %%
# 스케줄러 실행
while True:
    schedule.run_pending()
# Out:
# 1분간격 스케줄 실행중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 스케줄러 실행
# ----> 2 while True:
#       3     schedule.run_pending()
#
# KeyboardInterrupt:

# %% [markdown]
# 1시간에 한번씩 함수 실행

# %%
# 스케줄러 초기화
schedule.clear()

# %%
# 1시간에 한번씩 함수 실행
schedule.every(1).hour.do(message, '1시간')

# %%
# 스케줄러 실행
while True:
    schedule.run_pending()

# %% [markdown]
# #### 7.5.3. 일, 주 단위 실행

# %%
# 스케줄러 초기화
schedule.clear()

# %%
# 1일에 한번씩 함수 실행
schedule.every(1).days.do(message, '1일')

# 1주에 한번씩 함수 실행
schedule.every(1).weeks.do(message, '1주')

# %%
# 스케줄러 실행
while True:
    schedule.run_pending()

# %% [markdown]
# #### 7.5.4. 매일 정해진 시각에 실행

# %%
# 스케줄러 초기화
schedule.clear()

# %%
# 매일 13시 30분에 함수 실행
schedule.every().day.at("13:30").do(message, '1일')

# 매일 "11:11:11"에 함수 실행
schedule.every().day.at("11:11:11").do(message, '1일')

# %%
# 스케줄러 실행
while True:
    schedule.run_pending()

# %% [markdown]
# #### 7.5.5. 매주 정해진 시각에 실행

# %%
# 스케줄러 초기화
schedule.clear()

# %%
# 매주 월요일 13시 30분에 함수 실행
schedule.every().monday.at("13:30").do(message, '1주')

# %%
# 스케줄러 실행
while True:
    schedule.run_pending()

# %% [markdown]
# #### 7.5.6. 스케줄러 중지

# %%
# 스케줄러 초기화
schedule.clear()

# %%
# job 설정
job = schedule.every(1).seconds.do(message, '1초')  # 이벤트 등록

# %%
# 스케줄러 실행
count = 0

while True:
    schedule.run_pending()
    time.sleep(1)
    
    count = count + 1
    
    if count > 5:  # 5회 실행 후 스케줄러 중지
        schedule.cancel_job(job)
        print('스케줄러가 종료되었습니다 !')
        break
# Out:
# 1초간격 스케줄 실행중...
# 1초간격 스케줄 실행중...
# 1초간격 스케줄 실행중...
# 1초간격 스케줄 실행중...
# 1초간격 스케줄 실행중...
# 스케줄러가 종료되었습니다 !
